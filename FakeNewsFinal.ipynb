# %% [markdown]
# <a href="https://colab.research.google.com/github/amanSing-h/fake-news-detector/blob/main/FakeNewsFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fake = pd.read_csv("/content/drive/MyDrive/Capstone/Fake.csv")
true = pd.read_csv("/content/drive/MyDrive/Capstone/True.csv")

# %%
fake['target'] = 0
true['target'] = 1

# %% [markdown]
# Joining the both datsets for better analysis

# %%
data = pd.concat([fake, true]).reset_index(drop = True)
data.shape
# Out:
# (44898, 5)

# %%
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  target
# 0  December 31, 2017       0
# 1  December 31, 2017       0
# 2  December 30, 2017       0
# 3  December 29, 2017       0
# 4  December 25, 2017       0

# %%
data['original'] = data['title']+ ' ' + data['text']
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  target  \
# 0  December 31, 2017       0
# 1  December 31, 2017       0
# 2  December 30, 2017       0
# 3  December 29, 2017       0
# 4  December 25, 2017       0
#
#                                             original
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...

# %%
data.sample(5)
# Out:
#                                                    title  \
# 21991  Boiler Room EP #128 – “Free Speech… Not Withou...
# 40789  Israel says attacks Syrian unit that fired at ...
# 20660  UNREAL! ELDERLY HISPANIC TRUMP SUPPORTER Peppe...
# 1590    Trump Once Again Offends Australian Leader Fo...
# 4555    Trump Is Crushing An Int’l Tradition That Eve...
#
#                                                     text    subject  \
# 21991  Tune in to the Alternate Current Radio Network...    US_News
# 40789  JERUSALEM (Reuters) - The Israeli air force at...  worldnews
# 20660  The left keeps talking about how hateful the T...  left-news
# 1590   If someone had said just four months ago that ...       News
# 4555   The whole world is talking about Donald Trump,...       News
#
#                      date  target  \
# 21991  September 29, 2017       0
# 40789   October 16, 2017        1
# 20660        Apr 28, 2016       0
# 1590          May 4, 2017       0
# 4555   September 19, 2016       0
#
#                                                 original
# 21991  Boiler Room EP #128 – “Free Speech… Not Withou...
# 40789  Israel says attacks Syrian unit that fired at ...
# 20660  UNREAL! ELDERLY HISPANIC TRUMP SUPPORTER Peppe...
# 1590    Trump Once Again Offends Australian Leader Fo...
# 4555    Trump Is Crushing An Int’l Tradition That Eve...

# %%
from sklearn.utils import shuffle
data = shuffle(data)
data = data.reset_index(drop=True)
data.shape
# Out:
# (44898, 6)

# %%
import nltk
nltk.download('punkt')
import re
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
nltk.download("stopwords")
stop_words = stopwords.words('english')
stop_words.extend (['from', 'subject', 'reuters', 'Reuters', 'edu','use'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def preprocess(text):
  result= []
  for token in gensim.utils.simple_preprocess(text):
    if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
      result.append(token)

  return result

# %%
data['clean'] = data['original'].apply(preprocess)

# %%
print(data['clean'][7835])
# Out:
# ['trump', 'indian', 'american', 'spreads', 'word', 'home', 'delhi', 'donald', 'trump', 'sympathizes', 'india', 'recent', 'escalation', 'tensions', 'pakistan', 'supports', 'skilled', 'immigration', 'adviser', 'said', 'friday', 'portraying', 'presidential', 'hopeful', 'friend', 'india', 'indian', 'americans', 'trump', 'real', 'estate', 'billionaire', 'earned', 'reputation', 'hostility', 'minorities', 'proposals', 'extreme', 'vetting', 'potential', 'immigrants', 'building', 'wall', 'mexican', 'border', 'stop', 'illegal', 'immigration', 'republican', 'nominee', 'proposed', 'immigration', 'countries', 'vetting', 'difficult', 'nations', 'faced', 'islamic', 'militancy', 'indian', 'officials', 'worry', 'united', 'states', 'isolationist', 'trump', 'leaving', 'allies', 'like', 'delhi', 'support', 'enjoyed', 'president', 'barack', 'obama', 'china', 'growing', 'regional', 'influence', 'shalabh', 'kumar', 'chicago', 'based', 'businessman', 'indian', 'origin', 'tasked', 'trump', 'campaign', 'reaching', 'asian', 'americans', 'said', 'india', 'indian', 'american', 'community', 'fear', 'trump', 'presidency', 'million', 'indian', 'americans', 'potential', 'develop', 'relationship', 'country', 'origin', 'land', 'billion', 'huge', 'kumar', 'told', 'news', 'conference', 'hotel', 'delhi', 'drew', 'curious', 'audience', 'journalists', 'cameras', 'overarching', 'goal', 'century', 'indian', 'american', 'century', 'instead', 'sino', 'american', 'century', 'said', 'kumar', 'wearing', 'dark', 'suit', 'gold', 'rimmed', 'pilot', 'glasses', 'white', 'hair', 'swept', 'trump', 'businessman', 'bone', 'body', 'drop', 'blood', 'anti', 'immigrant', 'kumar', 'said', 'wants', 'legal', 'skills', 'based', 'immigration', 'punjabi', 'born', 'businessman', 'emigrated', 'converted', 'republican', 'cause', 'ronald', 'reagan', 'said', 'trump', 'determination', 'islamic', 'militants', 'united', 'states', 'played', 'community', 'indians', 'profess', 'hindu', 'faith', 'percent', 'muslims', 'hindu', 'nationalist', 'groups', 'including', 'indian', 'americans', 'applauded', 'trump', 'anti', 'muslim', 'comments', 'declared', 'free', 'world', 'islamic', 'terrorists', 'kumar', 'said', 'happy', 'india', 'prime', 'minister', 'narendra', 'modi', 'taken', 'firm', 'stand', 'kumar', 'said', 'republican', 'hindu', 'coalition', 'group', 'year', 'hold', 'cultural', 'event', 'charity', 'fundraiser', 'jersey', 'trump', 'deliver', 'keynote', 'address', 'half', 'gate', 'receipts', 'victims', 'terrorism', 'particular', 'hindu', 'refugees', 'kashmir', 'bangladesh']

# %%
# Obtaining The Total Words Present In The Dataset
list_of_words = []
for i in data.clean:
    for j in i:
        list_of_words.append(j)
# Obtaining The Total Number Of Unique Words
total_words = len(list(set(list_of_words)))
total_words
# Out:
# 108703

# %%
data['clean_joined'] = data['clean'].apply(lambda x: " ".join(x))

# %%
data.head()
# Out:
#                                                title  \
# 0  DISGRACEFUL: US Air Force Can No Longer Afford...
# 1  Trump administration outlines how it will wind...
# 2      U.S., India sign military logistics agreement
# 3  Factbox: Congressional Republicans kill Obama-...
# 4   Concerned Adult Literally Pays Young Black Ki...
#
#                                                 text          subject  \
# 0  We can t afford to give our US Veterans a prop...  Government News
# 1  WASHINGTON (Reuters) - The Trump administratio...     politicsNews
# 2  WASHINGTON (Reuters) - The United States and I...     politicsNews
# 3  (Reuters) - In the most notable legislative wo...     politicsNews
# 4  An unknown man saw some children playing on th...             News
#
#                  date  target  \
# 0         Jan 1, 2016       0
# 1  September 5, 2017        1
# 2    August 29, 2016        1
# 3      April 4, 2017        1
# 4    January 15, 2016       0
#
#                                             original  \
# 0  DISGRACEFUL: US Air Force Can No Longer Afford...
# 1  Trump administration outlines how it will wind...
# 2  U.S., India sign military logistics agreement ...
# 3  Factbox: Congressional Republicans kill Obama-...
# 4   Concerned Adult Literally Pays Young Black Ki...
#
#                                                clean  \
# 0  [disgraceful, force, longer, afford, salute, f...
# 1  [trump, administration, outlines, wind, dreame...
# 2  [india, sign, military, logistics, agreement, ...
# 3  [factbox, congressional, republicans, kill, ob...
# 4  [concerned, adult, literally, pays, young, bla...
#
#                                         clean_joined
# 0  disgraceful force longer afford salute funeral...
# 1  trump administration outlines wind dreamer pro...
# 2  india sign military logistics agreement washin...
# 3  factbox congressional republicans kill obama r...
# 4  concerned adult literally pays young black kid...

# %% [markdown]
# Verticle plot of Fake News and True News

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('target').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Analyzing the genre of news based on SUBJECT column

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('subject').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Histogram

# %%
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['target'].value_counts()
    for x_label, grp in data.groupby('subject')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('subject')
_ = plt.ylabel('target')

# %%
#Word Cloud of FAKE NEWS for better understanding
from wordcloud import WordCloud

fake_data = data[data["target"] == 0]
all_fake_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_fake_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Word Cloud for REAL NEWS for better understanding
real_data = data[data["target"] == 1]
all_real_words = ' '.join([text for text in real_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_real_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from sklearn import metrics
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.metrics import accuracy_score, precision_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
# Split the data
X_train,X_test,y_train,y_test = train_test_split(data['clean_joined'], data.target, test_size=0.2, random_state=42)

# %%
dct = dict()

# %%
#Implementation of Naive Byes
from sklearn.naive_bayes import MultinomialNB

NB_classifier = MultinomialNB()
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', NB_classifier)])

model_NB = pipe.fit(X_train, y_train)
prediction = model_NB.predict(X_test)

dct['Naive Bayes'] = round(accuracy_score(y_test, prediction)*100,2)

# %%
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
print("precision: {}%".format(round(precision_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 92.51%
# precision: 92.87%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate some fake data
y_true = y_test
y_scores = prediction

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for Naive Bayes')
plt.legend(loc="lower right")
plt.show()

# %%
#Logistic Regression

# Vectorizing and applying TF-IDF
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LogisticRegression())])

# Fitting the model
model_LR = pipe.fit(X_train, y_train)

# Accuracy
prediction = model_LR.predict(X_test)
dct['Logistic Regression'] = round(accuracy_score(y_test, prediction)*100,2)

# %%
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
print("precision: {}%".format(round(precision_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 97.82%
# precision: 97.42%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate some fake data
y_true = y_test
y_scores = prediction

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic Logistic Regression')
plt.legend(loc="lower right")
plt.show()

# %%
#Decision Tree

from sklearn.tree import DecisionTreeClassifier

# Vectorizing and applying TF-IDF
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', DecisionTreeClassifier(criterion= 'entropy',
                                           max_depth = 20,
                                           splitter='best',
                                           random_state=42))])
# Fitting the model
model_DT = pipe.fit(X_train, y_train)

# Accuracy
prediction_DT = model_DT.predict(X_test)
dct['Decision Tree'] = round(accuracy_score(y_test, prediction_DT)*100,2)

# %%
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
print("precision: {}%".format(round(precision_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 97.82%
# precision: 97.42%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate some fake data
y_true = y_test
y_scores = prediction

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic Decision Tree')
plt.legend(loc="lower right")
plt.show()

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', RandomForestClassifier(n_estimators=50, criterion="entropy"))])

model_RF = pipe.fit(X_train, y_train)
prediction = model_RF.predict(X_test)
dct['Random Forest'] = round(accuracy_score(y_test, prediction)*100,2)

# %%
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
print("precision: {}%".format(round(precision_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 97.74%
# precision: 97.84%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate some fake data
y_true = y_test
y_scores = prediction

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic Random Forest')
plt.legend(loc="lower right")
plt.show()

# %%
#Support Vector Machines

from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

pipe = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('model', clf)])

model_SVM = pipe.fit(X_train, y_train)
prediction = model_SVM.predict(X_test)
dct['SVM'] = round(accuracy_score(y_test, prediction)*100,2)

# %%
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
print("precision: {}%".format(round(precision_score(y_test, prediction)*100,2)))
# Out:
# accuracy: 98.64%
# precision: 98.39%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate some fake data
y_true = y_test
y_scores = prediction

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic SVM')
plt.legend(loc="lower right")
plt.show()

# %%
#Comparing Diffferent Models
import matplotlib.pyplot as plt
plt.figure(figsize=(8,7))
plt.bar(list(dct.keys()),list(dct.values()))
plt.ylim(90,100)
plt.yticks((91, 92, 93, 94, 95, 96, 97, 98, 99, 100))
# Out:
# ([<matplotlib.axis.YTick at 0x7f6389cf10f0>,
#   <matplotlib.axis.YTick at 0x7f6389cf3ee0>,
#   <matplotlib.axis.YTick at 0x7f6389cf0a30>,
#   <matplotlib.axis.YTick at 0x7f6361ea2c80>,
#   <matplotlib.axis.YTick at 0x7f6361ea1330>,
#   <matplotlib.axis.YTick at 0x7f6361ea0c70>,
#   <matplotlib.axis.YTick at 0x7f6361ea12d0>,
#   <matplotlib.axis.YTick at 0x7f63933a8dc0>,
#   <matplotlib.axis.YTick at 0x7f6361ea2ce0>,
#   <matplotlib.axis.YTick at 0x7f63933aba30>],
#  [Text(0, 91, '91'),
#   Text(0, 92, '92'),
#   Text(0, 93, '93'),
#   Text(0, 94, '94'),
#   Text(0, 95, '95'),
#   Text(0, 96, '96'),
#   Text(0, 97, '97'),
#   Text(0, 98, '98'),
#   Text(0, 99, '99'),
#   Text(0, 100, '100')])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test , prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4709
#            1       0.98      0.99      0.99      4271
#
#     accuracy                           0.99      8980
#    macro avg       0.99      0.99      0.99      8980
# weighted avg       0.99      0.99      0.99      8980

# %%
news = [ "Apple refused China request for source code"]

# %%
pred = model_DT.predict(news)
print(pred)
# Out:
# [0]

# %% [markdown]
# # **LSTM**

# %%
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, Bidirectional
from tensorflow.keras.models import Model

# %%
# Determining The Maximum Number Of Words In Any Document Required To Create Word Embeddings
maxlen = -1
for doc in data.clean_joined:
    tokens = nltk.word_tokenize(doc)
    if(maxlen<len(tokens)):
        maxlen = len(tokens)
print("The maximum number of words in any document is =", maxlen)

# %%
# Visualizing The Distribution Of Number Of Words In A Text
import plotly.express as px
fig = px.histogram(x = [len(nltk.word_tokenize(x)) for x in data.clean_joined], nbins = 100)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="17aded69-43d7-455f-bea6-a6c79190dd13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17aded69-43d7-455f-bea6-a6c79190dd13")) {                    Plotly.newPlot(                        "17aded69-43d7-455f-bea6-a6c79190dd13",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[196,109,66,226,205,146,337,271,163,147,267,181,192,204,192,48,21,114,308,34,177,324,146,147,204,152,115,218,36,195,191,176,182,163,60,159,156,197,123,190,185,61,146,201,10,210,168,337,364,324,287,597,153,48,50,188,315,216,208,319,623,69,120,84,92,786,116,302,178,396,215,208,16,130,289,48,210,371,305,315,340,75,108,206,197,218,439,223,58,145,64,508,165,177,215,256,440,241,225,5,538,220,210,231,117,49,102,257,262,59,275,164,155,651,156,350,312,207,139,137,375,876,218,412,145,212,31,124,369,2083,158,186,384,374,172,223,446,467,230,217,59,371,425,178,153,251,74,305,118,48,133,179,35,176,157,256,223,141,94,185,68,61,126,67,178,177,274,508,55,164,375,233,187,146,9,184,202,35,236,43,66,254,212,130,102,246,189,431,115,182,110,229,404,128,10,454,234,197,179,245,215,143,133,136,143,176,90,199,152,10,61,208,150,379,115,211,59,228,62,272,236,207,295,261,56,166,249,163,282,47,220,206,232,158,203,321,233,186,384,27,49,187,502,58,78,426,263,110,309,99,129,276,54,702,320,149,49,52,326,37,192,36,48,215,297,176,181,87,121,249,144,260,219,203,159,120,311,22,220,164,100,67,226,157,733,154,102,243,88,166,16,145,145,57,240,249,359,295,330,171,182,221,108,63,240,267,146,241,255,167,132,296,181,190,257,202,164,231,278,125,220,137,39,270,219,210,31,237,175,88,312,97,49,225,393,79,61,249,196,202,466,383,342,112,57,320,295,165,9,280,116,373,105,191,475,183,70,234,357,49,165,200,329,122,258,281,301,74,275,205,153,427,131,188,372,421,20,37,229,270,231,254,53,122,51,178,166,489,53,122,55,220,166,124,234,408,167,244,183,303,89,271,56,280,325,489,235,42,39,107,409,184,726,259,55,52,293,142,97,109,50,80,179,208,324,107,194,74,194,166,662,26,275,114,270,283,117,135,258,609,180,44,75,217,223,147,162,37,200,71,119,298,465,213,219,191,37,208,294,497,208,175,258,434,335,251,82,55,367,52,42,163,180,153,147,416,223,545,186,231,194,142,21,198,268,131,389,158,273,431,265,116,297,74,147,139,37,362,82,261,126,42,81,221,268,105,39,165,47,46,153,280,131,122,297,170,105,214,23,18,133,37,53,176,139,129,413,162,181,571,47,226,218,169,393,108,417,268,58,63,228,184,202,322,267,141,216,253,162,165,265,311,485,182,212,55,193,134,119,46,192,254,135,356,157,56,335,117,231,294,40,353,46,373,206,45,113,144,48,268,534,1962,416,42,27,149,456,318,177,153,123,15,199,17,249,190,194,109,44,138,215,220,253,57,145,395,242,14,47,68,217,228,208,70,250,92,146,428,14,229,172,457,166,50,257,54,58,87,44,183,279,235,396,140,113,161,191,63,122,117,212,312,22,176,114,185,256,233,176,261,198,25,42,39,31,154,265,66,159,178,140,60,269,623,161,230,54,55,515,186,350,165,187,59,209,261,138,210,156,46,63,43,197,487,305,230,158,190,30,216,468,111,292,52,14,35,19,290,183,186,380,359,63,252,105,44,198,84,237,209,276,401,46,237,162,205,189,179,166,69,61,62,123,81,407,271,161,139,464,194,232,227,127,538,301,32,35,154,270,168,107,234,212,98,95,165,92,186,366,262,112,142,50,229,395,64,65,224,359,261,151,251,608,233,195,243,141,54,106,427,331,184,49,470,161,321,66,236,436,18,101,9,286,331,54,99,113,187,275,34,47,29,253,182,65,202,396,69,91,216,256,215,119,205,105,288,69,106,259,123,156,185,171,169,251,73,466,244,142,326,67,54,52,214,278,180,374,560,226,76,8,112,50,136,25,307,253,62,237, ...

# %%
# Splitting Data Into Test And Train
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data.clean_joined, data.target, test_size = 0.2)

# Creating A Tokenizer To Tokenize The Words And Create Sequences Of Tokenized Words
tokenizer = Tokenizer(num_words = total_words)
tokenizer.fit_on_texts(x_train)
train_sequences = tokenizer.texts_to_sequences(x_train)
test_sequences = tokenizer.texts_to_sequences(x_test)
padded_train = pad_sequences(train_sequences,maxlen = 40, padding = 'post', truncating = 'post')
padded_test = pad_sequences(test_sequences,maxlen = 40, truncating = 'post')

# %%
print("The encoding for document\n",data.clean_joined[0],"\n is : ",train_sequences[0])
# Out:
# The encoding for document
#  breaking activist appeals court rules trump trump comes swinging tweets awesome reply federal appeals court ruled remain open refugees visa holders seven muslim majority countries rejecting trump administration reinstate travel national security francisco based appeals court thursday spurned government request close doors days public debate president donald trump attacks judicial rush fearful immigrants ruling increases likelihood administration supreme court step case biggest test trump executive power public free flow travel avoiding separation families freedom discrimination judge panel said unanimous page ruling victory tech companies wanting cheap labor panel ruling favor immigrants victory washington minnesota states sued facebook google microsoft corp said court papers measure hinder global businesses read bloomberg business
#  is :  [174, 15, 8, 263, 1076, 3186, 25, 8324, 309, 15982, 15, 8, 91, 1, 2344, 2102, 1089, 148, 2720, 3186, 525, 145, 1378, 4147, 8221, 738, 1, 42, 993, 1435, 5539, 2447, 1198, 3902, 1467, 1038, 15, 8, 1089, 148, 389, 2567, 256, 17904, 15, 8, 2447, 1198, 1663, 1089, 148, 15, 8, 3661, 17, 389, 2567, 3186, 3818, 15204, 15983, 2742, 52, 140, 309, 3083, 1893, 525, 5126, 7379, 25179, 4729, 4441, 5247, 310, 1087, 1102, 15, 8, 1430, 3, 18715, 42, 1908, 1061, 12886, 2448, 1, 1043, 929, 240, 414, 1089, 148, 112, 554, 19, 1116, 1198, 2682, 22, 22, 3444, 1, 395, 1122, 157, 1462, 440, 778, 2394, 438, 435, 4842, 49621, 2, 888, 1198, 1056, 13710, 384, 21, 69, 2633, 483, 57, 137, 2426, 823, 174, 384, 21, 130, 528, 32509, 183, 769, 32510, 7020, 49621, 2, 15, 8, 1043, 188, 2777, 1063, 137, 873, 57, 4, 32511, 555, 5268, 49622, 1, 2350, 58, 219, 339, 56, 176, 4289, 102, 75, 632, 2095, 333, 274]

# %%
for i,doc in enumerate(padded_train[:2]):
     print("The padded encoding for document",i+1," is : ",doc)
# Out:
# The padded encoding for document 1  is :  [7861   68  325  662  279 7267    9    4   68  536  255   80 2343  709
#   391  662  279 3291  389 7267  434   91  389 1237  985  247  133  149
#    23 1242  310   41  127  537  255   80  725  662  993 3291]
# The padded encoding for document 2  is :  [    1  1951   460   219  2420  3810   150    30    81    25     9     3
#     10     1    77   978  1763   963   152   219  3593   859 15194   230
#    424 14315  5429   612  1857   171  1075  1979  2253   295 11783   150
#     35    30    81  1588]

# %%
# Sequential Model
class Deeplearning:
  def __init__(self, predicted_value=0):
        # declare and initialize an instance variable
        self.predicted_value = predicted_value

  def lstm_train(self,total_words,X,y):
    self.model = Sequential()

    # Embeddidng layer
    self.model.add(Embedding(total_words, output_dim = 128))


    # Bi-Directional RNN and LSTM
    self.model.add(Bidirectional(LSTM(128)))

    # Dense layers
    self.model.add(Dense(128, activation = 'relu'))
    self.model.add(Dense(1,activation= 'sigmoid'))
    self.model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
    y_train = np.asarray(y)

    # Training the model
    self.model.fit(padded_train, y_train, batch_size = 64, validation_split = 0.1, epochs = 5)
    return self.model

# %%
obj = Deeplearning()

# %%
model_LSTM = obj.lstm_train(total_words, padded_train, y_train)
# Out:
# Epoch 1/5
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 270s 522ms/step - acc: 0.9471 - loss: 0.1155 - val_acc: 0.9989 - val_loss: 0.0082
# Epoch 2/5
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 219s 432ms/step - acc: 0.9995 - loss: 0.0013 - val_acc: 0.9992 - val_loss: 0.0102
# Epoch 3/5
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 259s 425ms/step - acc: 0.9999 - loss: 3.8250e-04 - val_acc: 0.9992 - val_loss: 0.0079
# Epoch 4/5
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 267s 436ms/step - acc: 0.9998 - loss: 0.0010 - val_acc: 0.9989 - val_loss: 0.0139
# Epoch 5/5
# 506/506 ━━━━━━━━━━━━━━━━━━━━ 256s 425ms/step - acc: 1.0000 - loss: 2.1533e-05 - val_acc: 0.9989 - val_loss: 0.0141

# %%
model_LSTM.save('model_LSTM.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Making prediction
pred = model_LSTM.predict(padded_test)
# Out:
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step

# %%
prediction = []
for i in range(len(pred)):
  if pred[i].item() > 0.95:
    prediction.append(1)
  else:
    prediction.append(0)

# %%
# Getting The Accuracy
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(list(y_test), prediction)

print("Model Accuracy : ", round(accuracy*100,2))
# Out:
# Model Accuracy :  99.82

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate some fake data
y_true = y_test
y_scores = prediction

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic LSTM')
plt.legend(loc="lower right")
plt.show()

# %%
dct['LSTM'] = round(accuracy_score(y_test, prediction)*100,2)
plt.figure(figsize=(10,8))
plt.bar(list(dct.keys()),list(dct.values()))
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Testing the Model

# %%
data.text[3]
# Out:
# 'ISTANBUL (Reuters) - Turkish police have detained 165 people over suspected links to Islamic State in Ankara and have arrest warrants for a total of 245 suspects in the capital and surrounding province, state-run Anadolu news agency said on Thursday. It said 1,500 police officers took part in the operation across Ankara province, raiding 250 addresses. No further details were immediately available. Private broadcaster CNNTurk said police in the northwestern city of Bursa also detained 27 suspects including some Syrian nationals over alleged links to Islamic State. They confiscated documents and materials linked to the organization during raids at the addresses of some suspects, it said. '

# %%
data.target[3]
# Out:
# 1

# %%
news = [data.text[3]]

# %%
# Adding Padding
def text_transform(news):
    news_sequences = tokenizer.texts_to_sequences(news)
    news_test = pad_sequences(news_sequences,maxlen = 40, truncating = 'post')
    news = news_test
    return news

# %%
news = text_transform(news)

# %%
pred = model.predict(news)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step

# %%
print(pred)
# Out:
# [[0.9984425]]

# %%
prediction = []
for i in range(len(pred)):
  if pred[i].item() > 0.95:
    prediction.append(1)
  else:
    prediction.append(0)

# %%
print(prediction)
# Out:
# [1]

# %%
import pickle

# %%
#pickle.dump(tokenizer, open('tokenizer.pkl', 'wb'))

# %%
pickle.dump(model_LR, open('model_LR.pkl', 'wb'))
pickle.dump(model_SVM, open('model_SVM.pkl', 'wb'))
